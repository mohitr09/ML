# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("wea.csv")

# %%
data = data.dropna()

# %%
sns.distplot(data['Rainfall'], bins= 20)

# %%
sns.kdeplot(data['Sunshine'], shade=True)

# %%
sns.distplot(data['WindGustSpeed'], hist=False)

# %%
sns.countplot(data['RainToday'])

# %%
sns.boxplot(data['MaxTemp'])

# %%
sns.relplot(x="Date",y="MaxTemp",data=data)

# %%
sns.relplot(x="Date",y="MaxTemp",hue="MaxTemp",data=data)

# %%
data.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
sns.relplot(x="Date",y="MinTemp",hue="RainToday",data=data)

# %%
sns.relplot(x="Date",y="MaxTemp",kind="line",data=data)

# %%
sns.relplot(x="Date",y="Rainfall",kind="line",data=data)

# %%
sns.relplot(x="Date",y="MaxTemp",kind="line",hue="RainTomorrow",data=data)

# %%
sns.relplot(x="Date",y="MaxTemp",kind="line",col="WindDir9am",col_wrap=4,height=3,data=data)

# %%
sns.catplot(x="WindGustDir",y="MaxTemp",data=data)

# %%
sns.catplot(y="MaxTemp",x="RainTomorrow",kind="swarm",data=data)

# %%
sns.catplot(x="MaxTemp",y="RainTomorrow",kind="swarm",hue="RainToday",data=data)

# %%
sns.catplot(x="WindGustDir",y="MaxTemp",data=data,kind="box")

# %%
sns.catplot(x='Cloud9am', y='MaxTemp', data=data,hue="RainToday",kind="box")

# %%
sns.catplot(x='Cloud9am', y='MaxTemp', data=data,hue="RainToday",kind="boxen")

# %%
sns.catplot(x="WindSpeed9am",y="Humidity9am",data=data.iloc[0:50],hue="RainToday",kind="bar")

# %%
sns.catplot(y="Date",x="MinTemp",kind="bar",data=data[0:10],hue="RainToday")

# %%
sns.countplot(x=data["RainToday"],data=data)

# %%
sns.jointplot(x="Temp9am",y="Humidity9am",data=data)

# %%
sns.jointplot(x="Temp9am",y="Humidity9am",data=data,kind="hex")

# %%
sns.jointplot(x="Temp9am",y="Humidity9am",data=data,kind="kde")

# %%
sns.pairplot(data=data[["Temp9am","Humidity9am","Pressure9am","Cloud9am","RainToday"]],hue="RainToday")

# %%
plt.figure(figsize=(15,8))
data['WindGustDir'].value_counts().plot(kind='pie')
